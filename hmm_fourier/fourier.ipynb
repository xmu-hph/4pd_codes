# %% [markdown]
# ### 比较窗口的微增量会对频谱带来什么影响？
# 1. 首先是采样点的变化。
# 2. 其次是幅值的变化

# %%
import numpy as np
import matplotlib.pyplot as plt
# 生成数据
w = np.arange(2 * np.pi, 300, 2 * np.pi)
#w = np.linspace(0,100,1000)
w = w[w != 1]
y = (-np.cos(w + 1) + 1) / (2 * (w + 1)) + (np.cos(w - 1) - 1) / (2 * (w - 1))
dw = 2
w1 = np.arange(2 * np.pi / (1 + dw), 100, 2 * np.pi / (1 + dw))
#w1 = np.linspace(0,100,1000)
w1 = w1[w1 != 1]
y1 = (-np.cos((w1 + 1) * (1 + dw)) + 1) / (2 * (w1 + 1)) + (np.cos((w1 - 1) * (1 + dw)) - 1) / (2 * (w1 - 1))
# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(w, y, label='y', color='blue')
plt.plot(w1, y1, label='y1', color='orange')
# 使用plt.scatter标注数据点
plt.scatter(w, y, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(w1, y1, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
w,y
# Out:
# (array([  6.28318531,  12.56637061,  18.84955592,  25.13274123,
#          31.41592654,  37.69911184,  43.98229715,  50.26548246,
#          56.54866776,  62.83185307,  69.11503838,  75.39822369,
#          81.68140899,  87.9645943 ,  94.24777961, 100.53096491,
#         106.81415022, 113.09733553, 119.38052084, 125.66370614,
#         131.94689145, 138.23007676, 144.51326207, 150.79644737,
#         157.07963268, 163.36281799, 169.64600329, 175.9291886 ,
#         182.21237391, 188.49555922, 194.77874452, 201.06192983,
#         207.34511514, 213.62830044, 219.91148575, 226.19467106,
#         232.47785637, 238.76104167, 245.04422698, 251.32741229,
#         257.61059759, 263.8937829 , 270.17696821, 276.46015352,
#         282.74333882, 289.02652413, 295.30970944]),
#  array([-1.19468971e-02, -2.92962170e-03, -1.29746041e-03, -7.28921401e-04,
#         -4.66243548e-04, -3.23679931e-04, -2.37761249e-04, -1.82013892e-04,
# ...

# %% [markdown]
# ### 比较窗口增大但是探测范围不变的效果
# 1. 窗口增大会影响采样点
# 2. 探测范围不变说明函数不会收到影响。

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成数据
w = np.arange(2 * np.pi, 100, 2 * np.pi)
w = w[w != 1]
y = (-np.cos(w + 1) + 1) / (2 * (w + 1)) + (np.cos(w - 1) - 1) / (2 * (w - 1))

dw = 0.001
w1 = np.arange(2 * np.pi / (1 + dw), 100, 2 * np.pi / (1 + dw))
w1 = w1[w1 != 1]
y1 = (-np.cos(w1 + 1) + 1) / (2 * (w1 + 1)) + (np.cos(w1 - 1) - 1) / (2 * (w1 - 1))

w2 = np.linspace(2 * np.pi / (1 + dw), 100, 1000)
w2 = w2[w2 != 1]
y2 = (-np.cos(w2 + 1) + 1) / (2 * (w2 + 1)) + (np.cos(w2 - 1) - 1) / (2 * (w2 - 1))

# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(w, y, label='y')
plt.plot(w1, y1, label='y1')
plt.plot(w2, y2, label='y2')
# 使用plt.scatter标注数据点
plt.scatter(w, y, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(w1, y1, color='orange', s=10)  # 标注第二个函数的点

# 添加图例
plt.legend()

# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')

# 显示图表
plt.grid(True)
plt.show()

# %%
# 在积分窗口[0,1]下，定积分随频率的变化为
w_test = np.linspace(0,100,1000)
w_test = w_test[w_test != 1]
cos_ = (1-np.cos(1+w_test))/(2*(1+w_test))+(1-np.cos(1-w_test))/(2*(1-w_test))
sin_ = -np.sin(1+w_test)/(2*(1+w_test))+np.sin(1-w_test)/(2*(1-w_test))
plt.figure(figsize = (10,5))
plt.plot(w_test,cos_,label = 'cos')
plt.plot(w_test,sin_,label = 'sin')
plt.scatter(w_test, cos_, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(w_test, sin_, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
# 时间窗口为1的情况下的频率采样点。
w_1 = np.arange(2*np.pi,100,2*np.pi)
w_1 = w_1[w_1!= 1]
cos_w1 = (1-np.cos(1+w_1))/(2*(1+w_1))+(1-np.cos(1-w_1))/(2*(1-w_1))
sin_w1 = -np.sin(1+w_1)/(2*(1+w_1))+np.sin(1-w_1)/(2*(1-w_1))
plt.figure(figsize = (10,5))
plt.plot(w_1,cos_w1,label = 'cos')
plt.plot(w_1,sin_w1,label = 'sin')
plt.scatter(w_1, cos_w1, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(w_1, sin_w1, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
#使用上面的采样点进行还原
t = np.linspace(0,2*np.pi,100)
tot = 0
for _ in range(len(w_1)):
    tot += cos_w1[_]*np.cos(w_1[_]*t)+sin_w1[_]*np.sin(w_1[_]*t)
origin_ = np.sin(t)
plt.figure(figsize = (10,5))
plt.plot(t,tot,label = 'pred')
plt.plot(t,origin_,label = 'origin')
plt.scatter(t,tot, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(t,origin_, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
# 假设说时间窗口变了，但是探测范围没变
w_1 = np.arange(np.pi,100,np.pi)
w_1 = w_1[w_1!= 1]
cos_w1 = (1-np.cos(1+w_1))/(2*(1+w_1))+(1-np.cos(1-w_1))/(2*(1-w_1))
sin_w1 = -np.sin(1+w_1)/(2*(1+w_1))+np.sin(1-w_1)/(2*(1-w_1))
plt.figure(figsize = (10,5))
plt.plot(w_1,cos_w1,label = 'cos')
plt.plot(w_1,sin_w1,label = 'sin')
plt.scatter(w_1, cos_w1, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(w_1, sin_w1, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
#使用上面的采样点进行还原
t = np.linspace(0,2*np.pi,100)
tot = 0
for _ in range(len(w_1)):
    tot += cos_w1[_]*np.cos(w_1[_]*t)+sin_w1[_]*np.sin(w_1[_]*t)
origin_ = np.sin(t)
plt.figure(figsize = (10,5))
plt.plot(t,tot,label = 'pred')
plt.plot(t,origin_,label = 'origin')
plt.scatter(t,tot, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(t,origin_, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
# 现在尝试一下等间隔但是错位会发生什么
w_1 = np.arange(2*np.pi-1,100,2*np.pi)
w_1 = w_1[w_1!= 1]
cos_w1 = (1-np.cos(1+w_1))/(2*(1+w_1))+(1-np.cos(1-w_1))/(2*(1-w_1))
sin_w1 = -np.sin(1+w_1)/(2*(1+w_1))+np.sin(1-w_1)/(2*(1-w_1))
plt.figure(figsize = (10,5))
plt.plot(w_1,cos_w1,label = 'cos')
plt.plot(w_1,sin_w1,label = 'sin')
plt.scatter(w_1, cos_w1, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(w_1, sin_w1, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
#使用上面的采样点进行还原
t = np.linspace(0,2*np.pi,100)
tot = 0
for _ in range(len(w_1)):
    tot += cos_w1[_]*np.cos(w_1[_]*t)+sin_w1[_]*np.sin(w_1[_]*t)
origin_ = np.sin(t)
plt.figure(figsize = (10,5))
plt.plot(t,tot,label = 'pred')
plt.plot(t,origin_,label = 'origin')
plt.scatter(t,tot, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(t,origin_, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
#拟合cos函数
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.layer1 = nn.Linear(1, 10)  # 输入层到隐藏层
        self.layer2 = nn.Linear(10, 20) # 隐藏层到隐藏层
        self.layer3 = nn.Linear(20, 20) # 隐藏层到隐藏层
        self.output_layer = nn.Linear(20, 1) # 隐藏层到输出层

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.relu(self.layer2(x))
        x = torch.relu(self.layer3(x))
        x = self.output_layer(x)
        return x
# 初始化模型
cos_model = NeuralNetwork()
x_tensor = torch.tensor(w_1,dtype = torch.float32).unsqueeze(1)
y_tensor = torch.tensor(cos_w1,dtype = torch.float32).unsqueeze(1)
# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = optim.Adam(cos_model.parameters(), lr=0.01)
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for train_index, test_index in kf.split(x_tensor):
    x_train, x_test = x_tensor[train_index], x_tensor[test_index]
    y_train, y_test = y_tensor[train_index], y_tensor[test_index]
    for epoch in range(1000):  # 训练1000个epoch
        cos_model.train()
        optimizer.zero_grad()
        output = cos_model(x_train)
        loss = criterion(output, y_train)
        loss.backward()
        optimizer.step()
    # 测试模型
    cos_model.eval()
    with torch.no_grad():
        test_output = cos_model(x_test)
        test_loss = criterion(test_output, y_test)
    print(f'Fold Test Loss: {test_loss.item()}')
# Out:
# Fold Test Loss: 7.143468974390998e-05
# Fold Test Loss: 0.0004803265619557351
# Fold Test Loss: 3.62687114829896e-06
# Fold Test Loss: 7.274842772631018e-08
# Fold Test Loss: 1.8561841841346904e-08

# %%
#拟合cos函数
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.layer1 = nn.Linear(1, 10)  # 输入层到隐藏层
        self.layer2 = nn.Linear(10, 20) # 隐藏层到隐藏层
        self.layer3 = nn.Linear(20, 20) # 隐藏层到隐藏层
        self.output_layer = nn.Linear(20, 1) # 隐藏层到输出层

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.relu(self.layer2(x))
        x = torch.relu(self.layer3(x))
        x = self.output_layer(x)
        return x
# 初始化模型
sin_model = NeuralNetwork()
x_tensor = torch.tensor(w_1,dtype = torch.float32).unsqueeze(1)
y_tensor = torch.tensor(sin_w1,dtype = torch.float32).unsqueeze(1)
# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = optim.Adam(sin_model.parameters(), lr=0.01)
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for train_index, test_index in kf.split(x_tensor):
    x_train, x_test = x_tensor[train_index], x_tensor[test_index]
    y_train, y_test = y_tensor[train_index], y_tensor[test_index]
    for epoch in range(1000):  # 训练1000个epoch
        sin_model.train()
        optimizer.zero_grad()
        output = sin_model(x_train)
        loss = criterion(output, y_train)
        loss.backward()
        optimizer.step()
    # 测试模型
    sin_model.eval()
    with torch.no_grad():
        test_output = sin_model(x_test)
        test_loss = criterion(test_output, y_test)
    print(f'Fold Test Loss: {test_loss.item()}')
# Out:
# Fold Test Loss: 0.002864767797291279
# Fold Test Loss: 6.3952215896279085e-06
# Fold Test Loss: 0.00013602188846562058
# Fold Test Loss: 9.073341061593965e-06
# Fold Test Loss: 3.1371164368465543e-06

# %%
with torch.no_grad():
    test = torch.tensor(np.linspace(0,100,300),dtype=torch.float32).unsqueeze(1)
    test_y = sin_model(test)
    plt.plot(test,test_y)
    plt.plot(x_tensor,y_tensor)
    plt.show()

# %%
#从上面的逼近模型中按照长时间窗口对应的频率点进行采样
with torch.no_grad():
    cos_am = cos_model(torch.tensor(w_1,dtype = torch.float32).unsqueeze(1))
    sin_am = sin_model(torch.tensor(w_1,dtype = torch.float32).unsqueeze(1))
#使用上面的采样点进行还原
t = np.linspace(0,2*np.pi,100)
tot = 0
for _ in range(len(w_1)):
    tot += cos_am[_]*np.cos(w_1[_]*t)+sin_am[_]*np.sin(w_1[_]*t)
origin_ = np.sin(t)
plt.figure(figsize = (10,5))
plt.plot(t,tot,label = 'pred')
plt.plot(t,origin_,label = 'origin')
plt.scatter(t,tot, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(t,origin_, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
# 观察对于逼近函数来说，采样频率偏移会带来什么影响
w_1 = np.arange(2,100,2)
w_1 = w_1[w_1!= 1]
with torch.no_grad():
    cos_am = cos_model(torch.tensor(w_1,dtype = torch.float32).unsqueeze(1))
    sin_am = sin_model(torch.tensor(w_1,dtype = torch.float32).unsqueeze(1))
#使用上面的采样点进行还原
t = np.linspace(0,2*np.pi,100)
tot = 0
for _ in range(len(w_1)):
    tot += cos_am[_]*np.cos(w_1[_]*t)+sin_am[_]*np.sin(w_1[_]*t)
origin_ = np.sin(t)
plt.figure(figsize = (10,5))
plt.plot(t,tot,label = 'pred')
plt.plot(t,origin_,label = 'origin')
plt.scatter(t,tot, color='blue', s=10)  # 标注第一个函数的点
plt.scatter(t,origin_, color='orange', s=10)  # 标注第二个函数的点
# 添加图例
plt.legend()
# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')
# 显示图表
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成数据
w = np.arange(2 * np.pi, 100, 0.05)
w = w[w != 1]
y = (-np.cos(w + 1) + 1) / (2 * (w + 1)) + (np.cos(w - 1) - 1) / (2 * (w - 1))

# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(w, y, label='y', color='blue')

# 使用plt.scatter标注数据点
plt.scatter(w, y, color='blue', s=10)  # 标注第一个函数的点

# 添加图例
plt.legend()

# 添加标题和轴标签
plt.title('Comparison of Different y Functions')
plt.xlabel('w')
plt.ylabel('y')

# 显示图表
plt.grid(True)
plt.show()

# %%
w2,y2
# Out:
# (array([  6.2769084 ,   6.37072531,   6.46454222,   6.55835912,
#           6.65217603,   6.74599294,   6.83980985,   6.93362676,
#           7.02744367,   7.12126058,   7.21507748,   7.30889439,
#           7.4027113 ,   7.49652821,   7.59034512,   7.68416203,
#           7.77797893,   7.87179584,   7.96561275,   8.05942966,
#           8.15324657,   8.24706348,   8.34088039,   8.43469729,
#           8.5285142 ,   8.62233111,   8.71614802,   8.80996493,
#           8.90378184,   8.99759875,   9.09141565,   9.18523256,
#           9.27904947,   9.37286638,   9.46668329,   9.5605002 ,
#           9.65431711,   9.74813401,   9.84195092,   9.93576783,
#          10.02958474,  10.12340165,  10.21721856,  10.31103546,
#          10.40485237,  10.49866928,  10.59248619,  10.6863031 ,
#          10.78012001,  10.87393692,  10.96775382,  11.06157073,
#          11.15538764,  11.24920455,  11.34302146,  11.43683837,
#          11.53065528,  11.62447218,  11.71828909,  11.812106  ,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# 自定义周期函数
def periodic_sin(x):
    return np.sin((x % 1))

# 生成数据
x = np.linspace(0, 5, 1000)  # 从0到5，生成1000个点
y = periodic_sin(x)

# 绘制图像
plt.figure(figsize=(10, 4))
plt.plot(x, y, label='Periodic sin(x)')
plt.xlabel('x')
plt.ylabel('sin(x % 1)')
plt.title('Periodic Function based on sin(x) in [0, 1]')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# 自定义周期函数
def periodic_sin(x,widow):
    return np.sin((x % widow))
# 生成数据
x = np.linspace(0, 5, 1000)  # 从0到5，生成1000个点
y = periodic_sin(x,1.5)
# 绘制图像
plt.figure(figsize=(10, 4))
plt.plot(x, y, label='Periodic sin(x)')
plt.xlabel('x')
plt.ylabel('sin(x % 1)')
plt.title('Periodic Function based on sin(x) in [0, 1]')
plt.legend()
plt.grid(True)
plt.show()

# %%
w=1.57
y = (-np.cos(w+1)+1)/(2*(w+1)) + (np.cos(w-1)-1)/(2*(w-1))
y
# Out:
# 0.21949572286482538

# %%
w = 2.5
y = (-np.cos((w+1)*2*np.pi)+1)/(2*(w+1)) + (np.cos((w-1)*2*np.pi)-1)/(2*(w-1))
y
# Out:
# -0.38095238095238093

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# 加载音频文件
audio_path = '../tts/examples/default.wav'
y, sr = librosa.load(audio_path, sr=None)

# 计算梅尔谱
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)

# 转换为对数刻度
S_dB = librosa.power_to_db(S, ref=np.max)

# 显示梅尔谱图
plt.figure(figsize=(10, 4))
librosa.display.specshow(S_dB, sr=sr, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()
